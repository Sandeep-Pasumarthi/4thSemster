# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n = list(range(11, 20))
msnt = [136, 268, 523, 1041, 2171, 4458, 9496, 20186, 42338]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 45000))
plt.xticks(n)
plt.title('Time taken by Merge Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [35847, 77842, 167977, 360540, 770251, 1638840, 3474355, 7342058, 15470811]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
#plt.ylim((0, 8))
plt.xticks(n)
plt.title('Number of Comparisions by Merge Sort Normal Distribution', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.0199068, 0.0181127, 0.0163139, 0.0150762, 0.0146659, 0.0141231, 0.0141570, 0.0142111, 0.0141188]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 0.1))
plt.xticks(n)
plt.title('Ratio of Time taken by Merge Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [5.28592, 5.26094, 5.23970, 5.22151, 5.20573, 5.191910, 5.17971, 5.16887, 5.15917]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((5, 5.3))
plt.xticks(n)
plt.title('Ratio of Comparisons by Merge Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msut = [165, 253, 530, 1042, 2189, 4574, 9589, 20287, 42824]

plt.figure(figsize = (20, 8))
plt.plot(n, msut)
plt.xlim((10, 20))
plt.ylim((0, 44000))
plt.xticks(n)
plt.title('Time taken by Merge Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(14, 24))
msut = [683741, 1465833, 3128377, 6649993, 14086099, 29745474, 62636667, 131564782, 275713231, 576592843]

plt.figure(figsize = (20, 8))
plt.plot(n, msut)
plt.xlim((13, 24))
#plt.ylim((0, 4))
plt.xticks(n)
plt.title('Number of Comparisions by Merge Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msut = [0.0243305, 0.0170990, 0.0165011, 0.0150907, 0.0147943, 0.0144874, 0.0142957, 0.0142822, 0.0142808]

plt.figure(figsize = (20, 8))
plt.plot(n, msut)
plt.xlim((10, 20))
plt.ylim((0, 0.1))
plt.xticks(n)
plt.title('Ratio of Time taken by Merge Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msut = [8.60785, 8.58286, 8.56163, 8.54343, 8.52765, 8.51383, 8.50164, 8.49080, 8.48110]

plt.figure(figsize = (20, 8))
plt.plot(n, msut)
plt.xlim((10, 20))
plt.ylim((8, 9))
plt.xticks(n)
plt.title('Ratio of Comparisons by Merge Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [248, 685, 2210, 7985, 30587, 118379, 466323, 1848089, 7288492]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 7400000))
plt.xticks(n)
plt.title('Time taken by Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [98089, 342218, 1283203, 4912353, 19369053, 76814961, 303891994, 1211848143, 556701879]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 1300000000))
plt.xticks(n)
plt.title('Comparisons by Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisons', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [2356, 4810, 9629, 20013, 39945, 78241, 159717, 321290, 616175]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 630000))
plt.xticks(n)
plt.title('Swaps by Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.0364221, 0.046228, 0.0689053, 0.115642, 0.206722, 0.375029, 0.695214, 1.30107, 2.43055]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 3))
plt.xticks(n)
plt.title('Ratio of Time taken by Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [14.464, 23.1287, 40.0269, 71.1429, 130.905, 243.353, 453.055, 853.151, 185.648]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 900))
plt.xticks(n)
plt.title('Ratio of Comparisons by Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.34741, 0.325083, 0.300357, 0.289837, 0.269967, 0.24787, 0.238113, 0.226191, 0.205481]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 0.4))
plt.xticks(n)
plt.title('Ratio of Swaps by Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Swaps to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [191, 410, 879, 1663, 3361, 7153, 15407, 32627, 68737]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 70000))
plt.xticks(n)
plt.title('Time taken by Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [39883, 86491, 197763, 435205, 911705, 1882070, 4100752, 8433562, 18477795]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 20000000))
plt.xticks(n)
plt.title('Number of Comparisions by Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [4050, 8915, 19539, 42697, 93440, 202901, 431476, 935843, 1964909]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 2000000))
plt.xticks(n)
plt.title('Number of Swaps by Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.0281644, 0.0277098, 0.0273874, 0.0240843, 0.0227153, 0.0226610, 0.0229694, 0.0229690, 0.0229219]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0.02, 0.03))
plt.xticks(n)
plt.title('Ratio of Time taken by Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [5.88106, 5.84548, 6.16882, 6.30284, 6.16174, 5.96247, 6.11357, 5.93730, 6.16193]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((5, 7))
plt.xticks(n)
plt.title('Ratio of Comparisons by Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.597204, 0.602518, 0.60948, 0.618357, 0.631512, 0.642798, 0.643262, 0.658841, 0.655253]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0.59, 0.7))
plt.xticks(n)
plt.title('Ratio of Swaps by Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Swaps to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [574, 1281, 2328, 8824, 31428, 117900, 470065, 1828346, 7258993]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 7500000))
plt.xticks(n)
plt.title('Time taken by Randomized Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [98532, 342016, 1283918, 4918992, 19402841, 76850791, 304037095, 1211836671, 556955761]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 1215000000))
plt.xticks(n)
plt.title('Number of Comparisions by Randomized Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [4388, 8878, 17818, 35814, 71802, 143291, 2877012, 577936, 1145713]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 3000000))
plt.xticks(n)
plt.title('Number of Swaps by Randomized Quick Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.0846407, 0.0865085, 0.0725861, 0.1277930, 0.212406, 0.373512, 0.700791, 1.28717, 2.42071]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 2.5))
plt.xticks(n)
plt.title('Ratio of Time taken by Randomized Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [14.5293, 23.1151, 40.0492, 71.2391, 131.134, 243.466, 453.271, 853.143, 185.732]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((14, 900))
plt.xticks(n)
plt.title('Ratio of Comparisons by Randomized Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.647045, 0.600018, 0.555797, 0.518675, 0.485272, 0.453951, 0.427889, 0.406872, 0.38207]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0.38, 0.70))
plt.xticks(n)
plt.title('Ratio of Swaps by Randomized Quick Sort with Normal Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Swaps to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [126, 569, 667, 1735, 4265, 7766, 16811, 34848, 73383]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 75000))
plt.xticks(n)
plt.title('Time taken by Randomized Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [38042, 83938, 182264, 395595, 852020, 1826475, 3898272, 8288850, 17487823]
plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 17500000))
plt.xticks(n)
plt.title('Number of Comparisions by Randomized Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Comparisions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [5378, 11676, 25294, 54468, 116217, 247431, 525384, 1117701, 2344398]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0, 2400000))
plt.xticks(n)
plt.title('Number of Swaps by Randomized Quick Sort with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Number of Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.0184322, 0.0383882, 0.0208057, 0.0251126, 0.0288249, 0.0246030, 0.0250625, 0.0245326, 0.0244813]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0.018, 0.04))
plt.xticks(n)
plt.title('Ratio of Time taken by Randomized Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Time Taken to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [5.60959, 5.67293, 5.68536, 5.72919, 5.75836, 5.78634, 5.8117, 5.83542, 5.8318]
plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((5.6, 5.9))
plt.xticks(n)
plt.title('Ratio of Comparisons by Randomized Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Comparisons to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 20))
msnt = [0.793028, 0.78912, 0.788995, 0.78883, 0.78545, 0.783871, 0.783264, 0.786871, 0.783472]
plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 20))
plt.ylim((0.78, 0.8))
plt.xticks(n)
plt.title('Ratio of Swaps by Randomized Quick Sort with Uniform Distribution Dataset to nlogn', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Ratio of Swaps to nlogn', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 15))
msnt = [798, 18841, 175693, 5178329]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 15))
plt.ylim((0, 5200000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(3) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 15))
msnt = [73801, 780031, 14483514, 445243417]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 15))
plt.ylim((0, 450000000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(3) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 15))
msnt = [26492, 271491, 5015449, 153067741]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 15))
plt.ylim((0, 155000000))
plt.xticks(n)
plt.title('Medians by Median of Medians(3) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 15))
msnt = [12924, 140692, 2636990, 80842698]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 15))
plt.ylim((0, 81000000))
plt.xticks(n)
plt.title('Partitions by Median of Medians(3) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [0, 1268, 10241, 135528, 1860820]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 1900000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(5) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [14603, 80550, 789614, 12889353, 179992963]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 180000000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(5) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [3861, 19566, 195605, 2992685, 42529538]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 43000000))
plt.xticks(n)
plt.title('Medians by Median of Medians(5) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [1469, 8667, 98638, 1450132, 21055144]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 22000000))
plt.xticks(n)
plt.title('Partitions by Median of Medians(5) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [0, 0, 3286, 48246, 317769]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 320000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(7) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [8323, 397786, 278569, 4580319, 33165131]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 35000000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(7) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [1845, 7834, 47937, 833169, 6249002]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 6300000))
plt.xticks(n)
plt.title('Medians by Median of Medians(7) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [660, 3306, 20718, 394740, 3132865]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 3200000))
plt.xticks(n)
plt.title('Partitions by Median of Medians(7) with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [0, 0, 1563, 1561, 5839]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 6000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(3) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [5619, 10911, 21811, 44811, 84054]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 85000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(3) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [3583, 6974, 14074, 29087, 54684]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 55000))
plt.xticks(n)
plt.title('Medians by Median of Medians(3) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [515, 816, 1308, 2346, 3548]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 4000))
plt.xticks(n)
plt.title('Partitions by Median of Medians(3) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [0, 0, 0, 2117, 3122]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 4000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(5) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [3399, 6736, 13375, 27039, 54915]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 60000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(5) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [1360, 2736, 5368, 10872, 22032]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 25000))
plt.xticks(n)
plt.title('Medians by Median of Medians(5) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [173, 268, 386, 602, 1077]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 2000))
plt.xticks(n)
plt.title('Partitions by Median of Medians(5) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [1562, 0, 0, 0, 1567]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 2000))
plt.xticks(n)
plt.title('Time taken by Median of Medians(7) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time in micro seconds', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [2791, 5736, 11449, 22872, 45350]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 50000))
plt.xticks(n)
plt.title('Swaps by Median of Medians(7) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Swaps', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [807, 1676, 3335, 6596, 13108]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 15000))
plt.xticks(n)
plt.title('Medians by Median of Medians(7) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Medians', fontdict = {'fontsize' : 15})
plt.show()

# %%
n = list(range(11, 16))
msnt = [87, 154, 232, 318, 491]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 16))
plt.ylim((0, 500))
plt.xticks(n)
plt.title('Partitions by Median of Medians(7) with Uniform Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Partitions', fontdict = {'fontsize' : 15})
plt.show()

# %%
a = list(map(float, input().split(" ")))
plt.figure(figsize = (20, 8))
sns.distplot(a, kde = False)
plt.title('Uniform Data Set', fontdict = {'fontsize' : 20})
plt.xlabel('Data', fontdict = {'fontsize' : 15})
plt.xlim(-100000, 1100000)
plt.show()

# %%
n = list(range(11, 18))
msnt = [0, 6507, 15593, 16014, 43796, 62509, 100396]

plt.figure(figsize = (20, 8))
plt.plot(n, msnt)
plt.xlim((10, 18))
plt.ylim((0, 110000))
plt.xticks(n)
plt.title('Time Taken by Bucket Sort with Normal Distribution Dataset', fontdict = {'fontsize' : 20})
plt.xlabel('Power of 2', fontdict = {'fontsize' : 15})
plt.ylabel('Time Taken in micro seconds', fontdict = {'fontsize' : 15})
plt.show()
